# %% [markdown]
# # SCRAPING

# %%
import os
import requests
from bs4 import BeautifulSoup
import time

def get_authors_from_letter(letter='a'):
    """
    Extracts authors from Project Gutenberg for a specific letter.
    
    Args:
        letter (str): The letter to extract authors for.
        
    Returns:
        list: List of dictionaries containing author information.
    """
    print(f"Scraping authors for letter: {letter}")
    
    # The correct URL format based on your sample
    url = f"https://www.gutenberg.org/browse/authors/{letter}.html.utf8"
    print(f"Fetching {url}")
    
    try:
        response = requests.get(url)
        
        if response.status_code != 200:
            print(f"Failed to fetch {url}. Status code: {response.status_code}")
            return []
        
        soup = BeautifulSoup(response.text, "html.parser")
        
        # Find the div containing author listings
        author_div = soup.find("div", class_="pgdbbyauthor")
        
        if not author_div:
            print("Could not find author listings div")
            return []
        
        authors = []
        
        # Find all h2 elements (author headings)
        author_headings = author_div.find_all("h2")
        print(f"Found {len(author_headings)} author headings for letter '{letter}'")
        
        for heading in author_headings:
            # Skip "See:" references
            if "See:" in heading.text:
                continue
            
            # Get author name - extract from heading text or anchor
            author_name = None
            author_id = None
            
            # Look for anchor with name attribute
            anchor = heading.find("a", attrs={"name": True})
            if anchor:
                author_id = anchor.get("name")
                # Clean up the author name by removing the permalink symbol
                author_name = heading.text.replace("¶", "").strip()
            else:
                # If no anchor with name, just use the heading text
                author_name = heading.text.strip()
            
            if not author_name:
                continue
            
            # Find the ul that follows this heading
            author_ul = heading.find_next("ul")
            if not author_ul:
                print(f"No book list found for {author_name}")
                continue
            
            # Count books in English where the author is listed as "Author"
            book_count = 0
            books = []
            
            # Find all li elements with class pgdbetext (etext entries)
            book_items = author_ul.find_all("li", class_="pgdbetext")
            
            for item in book_items:
                book_link = item.find("a")
                if not book_link:
                    continue
                    
                book_title = book_link.text.strip()
                book_url = book_link.get("href")
                
                # Check if book is in English and author is listed as Author
                item_text = item.text.lower()
                if "(english)" in item_text and "(as author)" in item_text:
                    book_count += 1
                    books.append({
                        "title": book_title,
                        "url": f"https://www.gutenberg.org{book_url}" if book_url.startswith("/") else book_url
                    })
            
            if book_count > 0:
                print(f"Author: {author_name} - {book_count} English books as Author")
                authors.append({
                    "id": author_id,
                    "name": author_name,
                    "book_count": book_count,
                    "books": books
                })
        
        return authors
        
    except Exception as e:
        print(f"Error scraping letter {letter}: {e}")
        return []

def get_prolific_authors(min_books=7, letters=None):
    """
    Gets a list of authors with at least the specified number of books.
    
    Args:
        min_books (int): Minimum number of books an author must have.
        letters (list): List of letters to scrape. If None, all letters are scraped.
        
    Returns:
        list: List of dictionaries containing author information.
    """
    if letters is None:
        # All lowercase letters plus 'other'
        letters = list('abcdefghijklmnopqrstuvwxyz') + ['other']
    
    prolific_authors = []
    
    for letter in letters:
        authors = get_authors_from_letter(letter)
        
        # Filter for prolific authors
        letter_prolific = [author for author in authors if author['book_count'] >= min_books]
        prolific_authors.extend(letter_prolific)
        
        print(f"Found {len(letter_prolific)} prolific authors for letter '{letter}'")
        
        # Be nice to the server
        time.sleep(1)
    
    # Sort by book count (descending)
    prolific_authors.sort(key=lambda x: x['book_count'], reverse=True)
    
    return prolific_authors

def save_author_list(authors, language, min_books):
    """
    Saves the list of authors to a text file with a dynamic filename based on language and min_books.
    
    Args:
        authors (list): List of author dictionaries.
        language (str): The language used for filtering.
        min_books (int): The minimum number of books used for filtering.
        
    Returns:
        bool: True if successful, False otherwise.
    """
    try:
        # Create the folder if it doesn't exist
        input_files_dir = "data/input_files"
        os.makedirs(input_files_dir, exist_ok=True)

        # Generate the filename based on language and minimum number of books
        filename = os.path.join(input_files_dir, f"{language}_{min_books}books.txt")
        
        with open(filename, 'w', encoding='utf-8') as f:
            f.write(f"Found {len(authors)} prolific authors:\n\n")
            
            for i, author in enumerate(authors):
                f.write(f"{i+1}. {author['name']} - {author['book_count']} books\n")
                
        print(f"Author list saved to {filename}")
        return True

    except Exception as e:
        print(f"Error saving author list: {e}")
        return False

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import os

def get_authors_from_letter(letter='a', language='english'):
    """
    Extracts authors from Project Gutenberg for a specific letter and language.
    
    Args:
        letter (str): The letter to extract authors for.
        language (str): The language of books to filter (e.g., 'english', 'french').
        
    Returns:
        list: List of dictionaries containing author information.
    """
    print(f"Scraping authors for letter: {letter} and language: {language}")
    
    # The correct URL format based on your sample
    url = f"https://www.gutenberg.org/browse/authors/{letter}.html.utf8"
    print(f"Fetching {url}")
    
    try:
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to fetch {url}. Status code: {response.status_code}")
            # Try alternative URL format if the first one fails
            url = f"https://www.gutenberg.org/browse/authors/{letter}"
            print(f"Trying alternative URL: {url}")
            response = requests.get(url)
            if response.status_code != 200:
                print(f"Failed to fetch alternative URL. Status code: {response.status_code}")
                return []

        soup = BeautifulSoup(response.text, "html.parser")
        
        # Find the div containing author listings
        author_div = soup.find("div", class_="pgdbbyauthor")
        if not author_div:
            print("Could not find author listings div")
            return []

        authors = []
        
        # Find all h2 elements (author headings)
        author_headings = author_div.find_all("h2")
        
        for heading in author_headings:
            # Skip "See:" references
            if "See:" in heading.text:
                continue

            # Get author name - extract from heading text or anchor
            author_name = None
            author_id = None

            # Look for anchor with name attribute
            anchor = heading.find("a", attrs={"name": True})
            if anchor:
                author_id = anchor.get("name")
                # Clean up the author name by removing the permalink symbol
                author_name = heading.text.replace("¶", "").strip()
            else:
                # If no anchor with name, just use the heading text
                author_name = heading.text.strip()

            if not author_name:
                continue

            # Skip "Anonymous", "Various", and "Unknown" authors
            if any(exclude in author_name.lower() for exclude in ["anonymous", "various", "unknown"]):
                continue

            # Find the ul that follows this heading
            author_ul = heading.find_next("ul")
            if not author_ul:
                print(f"No book list found for {author_name}")
                continue

            # Count books in the specified language where the author is listed as "Author"
            book_count = 0
            books = []

            # Find all li elements with class pgdbetext (etext entries)
            book_items = author_ul.find_all("li", class_="pgdbetext")
            
            for item in book_items:
                book_link = item.find("a")
                if not book_link:
                    continue
                
                book_title = book_link.text.strip()
                book_url = book_link.get("href")

                # Check if book is in the specified language and author is listed as Author
                item_text = item.text.lower()
                if f"({language})" in item_text and "(as author)" in item_text:
                    book_count += 1
                    books.append({
                        "title": book_title,
                        "url": f"https://www.gutenberg.org{book_url}" if book_url.startswith("/") else book_url
                    })

            # Only add authors who meet the minimum books requirement
            if book_count >= min_books:
                authors.append({
                    "name": author_name,
                    "book_count": book_count
                })
        
        return authors

    except Exception as e:
        print(f"Error scraping letter {letter}: {e}")
        return []

def get_prolific_authors(min_books=7, language='english', letters=None):
    """
    Gets a list of authors with at least the specified number of books.
    
    Args:
        min_books (int): Minimum number of books an author must have.
        language (str): Language to filter by.
        letters (list): List of letters to scrape. If None, all letters are scraped.
        
    Returns:
        list: List of dictionaries containing author information.
    """
    if letters is None:
        # All lowercase letters plus 'other'
        letters = list('abcdefghijklmnopqrstuvwxyz') + ['other']
    
    prolific_authors = []

    for letter in letters:
        authors = get_authors_from_letter(letter, language)
        
        # Filter for prolific authors
        letter_prolific = [author for author in authors if author['book_count'] >= min_books]
        prolific_authors.extend(letter_prolific)

        print(f"Found {len(letter_prolific)} prolific authors for letter '{letter}'")

        # Be nice to the server
        time.sleep(1)

    # Sort by book count (descending)
    prolific_authors.sort(key=lambda x: x['book_count'], reverse=True)

    return prolific_authors

def save_author_list(authors, filename="prolific_authors.txt"):
    """
    Saves the list of authors to a text file.
    
    Args:
        authors (list): List of author dictionaries.
        filename (str): Name of the file to save to.
        
    Returns:
        bool: True if successful, False otherwise.
    """
    try:
        with open(filename, 'w', encoding='utf-8') as f:
            f.write(f"Found {len(authors)} prolific authors:\n\n")
            
            for i, author in enumerate(authors):
                # Print only the author name and book count
                f.write(f"{i+1}. {author['name']} - {author['book_count']} books\n")
                
        print(f"Author list saved to {filename}")
        return True

    except Exception as e:
        print(f"Error saving author list: {e}")
        return False

if __name__ == "__main__":
    # Get inputs from the user
    language = input("Enter language (e.g., 'english'): ").lower()
    min_books = int(input("Enter minimum number of books per author: "))

    # Get authors from all letters
    print("Starting to scrape prolific authors...")
    prolific_authors = get_prolific_authors(min_books=min_books, language=language)
    
    print(f"\nFound {len(prolific_authors)} prolific authors:")
    for i, author in enumerate(prolific_authors):
        # Print only the author name and book count
        print(f"{i+1}. {author['name']} - {author['book_count']} books")

    # Save the author list to a file
    save_author_list(prolific_authors)
# Out:
# Enter language (e.g., 'english'): english
# Enter minimum number of books per author: 10
# Starting to scrape prolific authors...
# Scraping authors for letter: a and language: english
# Fetching https://www.gutenberg.org/browse/authors/a.html.utf8
# Found 44 prolific authors for letter 'a'
# Scraping authors for letter: b and language: english
# Fetching https://www.gutenberg.org/browse/authors/b.html.utf8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 186
#     184 # Get authors from all letters
#     185 print("Starting to scrape prolific authors...")
# --> 186 prolific_authors = get_prolific_authors(min_books=min_books, language=language)
#     188 print(f"\nFound {len(prolific_authors)} prolific authors:")
#     189 for i, author in enumerate(prolific_authors):
#     190     # Print only the author name and book count
#
# Cell In[3], line 137, in get_prolific_authors(min_books, language, letters)
#     134 prolific_authors = []
#     136 for letter in letters:
# --> 137     authors = get_authors_from_letter(letter, language)
#     139     # Filter for prolific authors
#     140     letter_prolific = [author for author in authors if author['book_count'] >= min_books]
#
# Cell In[3], line 25, in get_authors_from_letter(letter, language)
#      22 print(f"Fetching {url}")
#      24 try:
# ---> 25     response = requests.get(url)
#      26     if response.status_code != 200:
#      27         print(f"Failed to fetch {url}. Status code: {response.status_code}")
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/anaconda3/lib/python3.11/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import os
import requests
from bs4 import BeautifulSoup
import re
import time

def get_authors_from_letter(letter='a', language='english', min_books=7):
    """
    Extracts authors from Project Gutenberg for a specific letter and language.
    
    Args:
        letter (str): The letter to extract authors for.
        language (str): The language of books to filter (e.g., 'english', 'french').
        min_books (int): The minimum number of books an author must have.
        
    Returns:
        list: List of dictionaries containing author information.
    """
    print(f"Scraping authors for letter: {letter} and language: {language}")
    
    # The correct URL format based on your sample
    url = f"https://www.gutenberg.org/browse/authors/{letter}.html.utf8"
    print(f"Fetching {url}")
    
    try:
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to fetch {url}. Status code: {response.status_code}")
            # Try alternative URL format if the first one fails
            url = f"https://www.gutenberg.org/browse/authors/{letter}"
            print(f"Trying alternative URL: {url}")
            response = requests.get(url)
            if response.status_code != 200:
                print(f"Failed to fetch alternative URL. Status code: {response.status_code}")
                return []

        soup = BeautifulSoup(response.text, "html.parser")
        
        # Find the div containing author listings
        author_div = soup.find("div", class_="pgdbbyauthor")
        if not author_div:
            print("Could not find author listings div")
            return []

        authors = []
        
        # Find all h2 elements (author headings)
        author_headings = author_div.find_all("h2")
        
        for heading in author_headings:
            # Skip "See:" references
            if "See:" in heading.text:
                continue

            # Get author name - extract from heading text or anchor
            author_name = None
            author_id = None

            # Look for anchor with name attribute
            anchor = heading.find("a", attrs={"name": True})
            if anchor:
                author_id = anchor.get("name")
                # Clean up the author name by removing the permalink symbol
                author_name = heading.text.replace("¶", "").strip()
            else:
                # If no anchor with name, just use the heading text
                author_name = heading.text.strip()

            if not author_name:
                continue

            # Skip "Anonymous", "Various", and "Unknown" authors
            if any(exclude in author_name.lower() for exclude in ["anonymous", "various", "unknown"]):
                continue

            # Find the ul that follows this heading
            author_ul = heading.find_next("ul")
            if not author_ul:
                print(f"No book list found for {author_name}")
                continue

            # Count books in the specified language where the author is listed as "Author"
            book_count = 0
            books = []

            # Find all li elements with class pgdbetext (etext entries)
            book_items = author_ul.find_all("li", class_="pgdbetext")
            
            for item in book_items:
                book_link = item.find("a")
                if not book_link:
                    continue
                
                book_title = book_link.text.strip()
                book_url = book_link.get("href")

                # Check if book is in the specified language and author is listed as Author
                item_text = item.text.lower()
                if f"({language})" in item_text and "(as author)" in item_text:
                    book_count += 1
                    books.append({
                        "title": book_title,
                        "url": f"https://www.gutenberg.org{book_url}" if book_url.startswith("/") else book_url
                    })

            # Only add authors who meet the minimum books requirement
            if book_count >= min_books:
                authors.append({
                    "name": author_name,
                    "book_count": book_count
                })
        
        return authors

    except Exception as e:
        print(f"Error scraping letter {letter}: {e}")
        return []

def get_prolific_authors(min_books=7, language='english', letters=None):
    """
    Gets a list of authors with at least the specified number of books.
    
    Args:
        min_books (int): Minimum number of books an author must have.
        language (str): Language to filter by.
        letters (list): List of letters to scrape. If None, all letters are scraped.
        
    Returns:
        list: List of dictionaries containing author information.
    """
    if letters is None:
        # All lowercase letters plus 'other'
        letters = list('abcdefghijklmnopqrstuvwxyz') + ['other']
    
    prolific_authors = []

    for letter in letters:
        authors = get_authors_from_letter(letter, language, min_books)
        
        # Filter for prolific authors
        letter_prolific = [author for author in authors if author['book_count'] >= min_books]
        prolific_authors.extend(letter_prolific)

        print(f"Found {len(letter_prolific)} prolific authors for letter '{letter}'")

        # Be nice to the server
        time.sleep(1)

    # Sort by book count (descending)
    prolific_authors.sort(key=lambda x: x['book_count'], reverse=True)

    return prolific_authors

def save_author_list(authors, language, min_books):
    """
    Saves the list of authors to a text file with a dynamic filename based on language and min_books.
    
    Args:
        authors (list): List of author dictionaries.
        language (str): The language used for filtering.
        min_books (int): The minimum number of books used for filtering.
        
    Returns:
        bool: True if successful, False otherwise.
    """
    try:
        # Set the path to the root directory directly
        root_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))  # Project root
        input_files_dir = os.path.join(root_dir, 'data', 'input_files')
        os.makedirs(input_files_dir, exist_ok=True)

        # Generate the filename based on language and minimum number of books
        filename = os.path.join(input_files_dir, f"{language}_{min_books}books.txt")
        
        with open(filename, 'w', encoding='utf-8') as f:
            f.write(f"Found {len(authors)} prolific authors:\n\n")
            
            for i, author in enumerate(authors):
                f.write(f"{i+1}. {author['name']} - {author['book_count']} books\n")
                
        print(f"Author list saved to {filename}")
        return True

    except Exception as e:
        print(f"Error saving author list: {e}")
        return False


if __name__ == "__main__":
    # Get inputs from the user
    language = input("Enter language (e.g., 'english'): ").lower()
    min_books = int(input("Enter minimum number of books per author: "))

    # Get authors from all letters
    print("Starting to scrape prolific authors...")
    prolific_authors = get_prolific_authors(min_books=min_books, language=language)
    
    print(f"\nFound {len(prolific_authors)} prolific authors:")
    for i, author in enumerate(prolific_authors):
        # Print only the author name and book count
        print(f"{i+1}. {author['name']} - {author['book_count']} books")

    # Save the author list to a file
    save_author_list(prolific_authors, language, min_books)
# Out:
# Enter language (e.g., 'english'): english
# Enter minimum number of books per author: 20
# Starting to scrape prolific authors...
# Scraping authors for letter: a and language: english
# Fetching https://www.gutenberg.org/browse/authors/a.html.utf8
# Found 18 prolific authors for letter 'a'
# Scraping authors for letter: b and language: english
# Fetching https://www.gutenberg.org/browse/authors/b.html.utf8
# Found 48 prolific authors for letter 'b'
# Scraping authors for letter: c and language: english
# Fetching https://www.gutenberg.org/browse/authors/c.html.utf8
# Found 39 prolific authors for letter 'c'
# Scraping authors for letter: d and language: english
# Fetching https://www.gutenberg.org/browse/authors/d.html.utf8
# Found 21 prolific authors for letter 'd'
# Scraping authors for letter: e and language: english
# Fetching https://www.gutenberg.org/browse/authors/e.html.utf8
# Found 8 prolific authors for letter 'e'
# Scraping authors for letter: f and language: english
# Fetching https://www.gutenberg.org/browse/authors/f.html.utf8
# Found 15 prolific authors for letter 'f'
# Scraping authors for letter: g and language: english
# Fetching https://www.gutenberg.org/browse/authors/g.html.utf8
# Found 20 prolific authors for letter 'g'
# Scraping authors for letter: h and language: english
# Fetching https://www.gutenberg.org/browse/authors/h.html.utf8
# Found 37 prolific authors for letter 'h'
# Scraping authors for letter: i and language: english
# Fetching https://www.gutenberg.org/browse/authors/i.html.utf8
# Found 3 prolific authors for letter 'i'
# Scraping authors for letter: j and language: english
# Fetching https://www.gutenberg.org/browse/authors/j.html.utf8
# Found 8 prolific authors for letter 'j'
# Scraping authors for letter: k and language: english
# Fetching https://www.gutenberg.org/browse/authors/k.html.utf8
# Found 6 prolific authors for letter 'k'
# Scraping authors for letter: l and language: english
# Fetching https://www.gutenberg.org/browse/authors/l.html.utf8
# Found 28 prolific authors for letter 'l'
# Scraping authors for letter: m and language: english
# Fetching https://www.gutenberg.org/browse/authors/m.html.utf8
# Found 39 prolific authors for letter 'm'
# Scraping authors for letter: n and language: english
# Fetching https://www.gutenberg.org/browse/authors/n.html.utf8
# Found 5 prolific authors for letter 'n'
# Scraping authors for letter: o and language: english
# Fetching https://www.gutenberg.org/browse/authors/o.html.utf8
# Found 6 prolific authors for letter 'o'
# Scraping authors for letter: p and language: english
# Fetching https://www.gutenberg.org/browse/authors/p.html.utf8
# Found 15 prolific authors for letter 'p'
# Scraping authors for letter: q and language: english
# Fetching https://www.gutenberg.org/browse/authors/q.html.utf8
# Found 2 prolific authors for letter 'q'
# Scraping authors for letter: r and language: english
# Fetching https://www.gutenberg.org/browse/authors/r.html.utf8
# Found 16 prolific authors for letter 'r'
# Scraping authors for letter: s and language: english
# Fetching https://www.gutenberg.org/browse/authors/s.html.utf8
# Found 40 prolific authors for letter 's'
# Scraping authors for letter: t and language: english
# Fetching https://www.gutenberg.org/browse/authors/t.html.utf8
# Found 13 prolific authors for letter 't'
# Scraping authors for letter: u and language: english
# Fetching https://www.gutenberg.org/browse/authors/u.html.utf8
# Found 2 prolific authors for letter 'u'
# Scraping authors for letter: v and language: english
# Fetching https://www.gutenberg.org/browse/authors/v.html.utf8
# Found 6 prolific authors for letter 'v'
# Scraping authors for letter: w and language: english
# Fetching https://www.gutenberg.org/browse/authors/w.html.utf8
# Found 27 prolific authors for letter 'w'
# Scraping authors for letter: x and language: english
# Fetching https://www.gutenberg.org/browse/authors/x.html.utf8
# Found 0 prolific authors for letter 'x'
# Scraping authors for letter: y and language: english
# Fetching https://www.gutenberg.org/browse/authors/y.html.utf8
# Found 5 prolific authors for letter 'y'
# Scraping authors for letter: z and language: english
# Fetching https://www.gutenberg.org/browse/authors/z.html.utf8
# Found 1 prolific authors for letter 'z'
# Scraping authors for letter: other and language: english
# Fetching https://www.gutenberg.org/browse/authors/other.html.utf8
# Found 0 prolific authors for letter 'other'
#
# Found 428 prolific authors:
# 1. Lytton, Edward Bulwer - 218 books
# 2. Lytton, Edward Bulwer Lytton, Baron, 1803-1873 - 218 books
# 3. Shakespeare, William, 1564-1616 - 183 books
# 218. Hichens, Robert, 1864-1950 - 30 books
# 219. Ibsen, Henrik, 1828-1906 - 30 books
# 220. Leiber, Fritz, 1910-1992 - 30 books
# 221. Morley, John, 1838-1923 - 30 books
# 222. Abbott, John S. C. (John Stevens Cabot), 1805-1877 - 29 books
# 223. Farjeon, B. L. (Benjamin Leopold), 1833-1903 - 29 books
# 224. Gaskell, Elizabeth Cleghorn, 1810-1865 - 29 books
# 225. Hardy, Thomas, 1840-1928 - 29 books
# 226. Holinshed, Raphael, -1580? - 29 books
# 227. Holley, Marietta, 1836-1926 - 29 books
# 228. Hornung, E. W. (Ernest William), 1866-1921 - 29 books
# 229. Howard, Robert E. (Robert Ervin), 1906-1936 - 29 books
# 230. Orczy, Emmuska Orczy, Baroness, 1865-1947 - 29 books
# 231. Plato, 427? BC-347? BC - 29 books
# 232. Roberts, Charles G. D., Sir, 1860-1943 - 29 books
# 233. Smith, Francis Hopkinson, 1838-1915 - 29 books
# 234. Southworth, Emma Dorothy Eliza Nevitte, 1819-1899 - 29 books
# 235. Tracy, Louis, 1863-1928 - 29 books
# 236. Vandercook, Margaret, 1876-1958 - 29 books
# 237. Wallace, Edgar, 1875-1932 - 29 books
# 238. Weyman, Stanley John, 1855-1928 - 29 books
# 239. Chapman, Allen - 28 books
# 240. Chautauqua Institution - 28 books
# 241. Chautauqua Literary and Scientific Circle - 28 books
# 242. Grey, Zane, 1872-1939 - 28 books
# 243. Hough, Emerson, 1857-1923 - 28 books
# 244. Irving, Washington, 1783-1859 - 28 books
# 245. Jókai, Mór, 1825-1904 - 28 books
# 246. King, Charles, 1844-1933 - 28 books
# 247. Morris, William, 1834-1896 - 28 books
# 248. Nicholson, Meredith, 1866-1947 - 28 books
# 249. Page, Thomas Nelson, 1853-1922 - 28 books
# 250. Penrose, Margaret - 28 books
# 251. Tarkington, Booth, 1869-1946 - 28 books
# 252. Weymouth, Richard Francis, 1822-1902 - 28 books
# 253. Wilcox, Ella Wheeler, 1850-1919 - 28 books
# 254. Braz, Anatole Le - 27 books
# 255. Brazil, Angela, 1869-1947 - 27 books
# 256. Chekhov, Anton Pavlovich, 1860-1904 - 27 books
# 257. Martineau, Harriet, 1802-1876 - 27 books
# 258. Maugham, W. Somerset (William Somerset), 1874-1965 - 27 books
# 259. Mitford, Algernon Bertram - 27 books
# 260. Mitford, Bertram, 1855-1914 - 27 books
# 261. Montaigne, Michel de, 1533-1592 - 27 books
# 262. Ouida, 1839-1908 - 27 books
# 263. Seawell, Molly Elliot, 1860-1916 - 27 books
# 264. Swinburne, Algernon Charles, 1837-1909 - 27 books
# 265. Vaknin, Samuel, 1961- - 27 books
# 266. Anderson, Poul, 1926-2001 - 26 books
# 267. Barr, Amelia E., 1831-1919 - 26 books
# 268. Bierbower, Elsie Jane - 26 books
# 269. Bierce, Ambrose, 1842-1914? - 26 books
# 270. Brinton, Daniel G. (Daniel Garrison), 1837-1899 - 26 books
# 271. Burroughs, John, 1837-1921 - 26 books
# 272. Croker, B. M. (Bithia Mary), 1849?-1920 - 26 books
# 273. Everett-Green, Evelyn, 1856-1932 - 26 books
# 274. Fletcher, John, 1579-1625 - 26 books
# 275. Locke, William John, 1863-1930 - 26 books
# 276. Lynde, Francis, 1856-1930 - 26 books
# 277. Nietschmann, H. (Hermann) - 26 books
# 278. Nietzsche, Friedrich Wilhelm, 1844-1900 - 26 books
# 279. Raineval, Melville Henry Massue, marquis de Ruvigny et - 26 books
# 280. Raine, William MacLeod, 1871-1954 - 26 books
# 281. Young, Clarence - 26 books
# 282. Aycock, Roger D., 1914-2004 - 25 books
# 283. Blackwood, Algernon, 1869-1951 - 25 books
# 284. Burton, Richard Francis, Sir, 1821-1890 - 25 books
# 285. Carroll, Lewis, 1832-1898 - 25 books
# 286. Edgeworth, Maria, 1768-1849 - 25 books
# 287. Freeman, Mary Eleanor Wilkins, 1852-1930 - 25 books
# 288. Giberne, Agnes, 1845-1939 - 25 books
# 289. Guernsey, H. W. - 25 books
# 290. Guernsey, Lucy Ellen, 1826-1899 - 25 books
# 291. Hearn, Lafcadio, 1850-1904 - 25 books
# 292. Johnson, Samuel, 1709-1784 - 25 books
# 293. Maeterlinck, Maurice, 1862-1949 - 25 books
# 294. Shelley, Mary Wollstonecraft, 1797-1851 - 25 books
# 295. Southey, Robert, 1774-1843 - 25 books
# 296. Stevenson, Burton Egbert, 1872-1962 - 25 books
# 297. Strindberg, August, 1849-1912 - 25 books
# 298. Webster, Frank V. - 25 books
# 299. Butler, Ellis Parker, 1869-1937 - 24 books
# 300. Calvert, Albert Frederick, 1872-1946 - 24 books
# 301. Cordón, Jorge Camacho - 24 books
# 302. Corelli, Marie, 1855-1924 - 24 books
# 303. Emerine J. Hamilton Reading Room - 24 books
# 304. Emerson, Alice B. - 24 books
# 305. Fabre, Jean-Henri, 1823-1915 - 24 books
# 306. Font, Claudi Planas i - 24 books
# 307. Fontenay, Charles L., 1917-2007 - 24 books
# 308. Garlanda, Ada - 24 books
# 309. Garland, Hamlin, 1860-1940 - 24 books
# 310. Gissing, George, 1857-1903 - 24 books
# 311. Laumer, Keith, 1925-1993 - 24 books
# 312. Lefebvre, Renato - 24 books
# 313. Le Feuvre, Amy, 1861-1929 - 24 books
# 314. Lincoln, Abraham, 1809-1865 - 24 books
# 315. Macaulay, Thomas Babington - 24 books
# 316. Macaulay, Thomas Babington Macaulay, Baron, 1800-1859 - 24 books
# 317. Marks, Winston K. (Winston Kinney), 1915-1979 - 24 books
# 318. May, Sophie, 1833-1906 - 24 books
# 319. Potter, Beatrice - 24 books
# 320. Potter, Beatrix, 1866-1943 - 24 books
# 321. Raymond, Evelyn, 1843-1910 - 24 books
# 322. Smith, J. Jay (John Jay), 1798-1881 - 24 books
# 323. Stephens, Ann S. (Ann Sophia), 1810-1886 - 24 books
# 324. Stooke, Eleanora H. - 24 books
# 325. White, Stewart Edward, 1873-1946 - 24 books
# 326. Yates, Edmund, 1831-1894 - 24 books
# 327. Beaumont, Francis, 1584-1616 - 23 books
# 328. Church, J. (John), 1780?-1825? - 23 books
# 329. Coleridge, Samuel Taylor, 1772-1834 - 23 books
# 330. Coppel, Alfred, 1921-2004 - 23 books
# 331. Guizot de Witt, Madame (Henriette Elizabeth) - 23 books
# 332. Guizot, François, 1787-1874 - 23 books
# 333. Long, Frank Belknap, 1903-1994 - 23 books
# 334. Marsh, Richard, 1857-1915 - 23 books
# 335. Masó, Miguel Saderra - 23 books
# 336. Mason, A. E. W. (Alfred Edward Woodley), 1865-1948 - 23 books
# 337. Riley, James Whitcomb, 1849-1916 - 23 books
# 338. Ritchie, J. Ewing (James Ewing), 1820-1898 - 23 books
# 339. Sumner, Charles, 1811-1874 - 23 books
# 340. Turco‏, Jacopo - 23 books
# 341. Turgenev, Ivan Sergeevich, 1818-1883 - 23 books
# 342. Vaizey, George de Horne, Mrs., 1857-1917 - 23 books
# 343. Voltaire, 1694-1778 - 23 books
# 344. Barr, Robert, 1850-1912 - 22 books
# 345. Blackmore, R. D. (Richard Doddridge), 1825-1900 - 22 books
# 346. Crane, Walter, 1845-1915 - 22 books
# 347. De Quincey, Thomas, 1785-1859 - 22 books
# 348. Dryden, John, 1631-1700 - 22 books
# 349. FWP - 22 books
# 350. Fyfe, H. B. (Horace Bowne), 1918-1997 - 22 books
# 351. Harmon, Jim, 1933-2010 - 22 books
# 352. Herford, Oliver, 1863-1935 - 22 books
# 353. Hubbard, Elbert, 1856-1915 - 22 books
# 354. MacGrath, Harold, 1871-1932 - 22 books
# 355. Molière, 1622-1673 - 22 books
# 356. Moore, Frank Frankfort, 1855-1931 - 22 books
# 357. Munroe, Kirk, 1850-1930 - 22 books
# 358. Poe, Edgar Allan, 1809-1849 - 22 books
# 359. Pyle, Howard, 1853-1911 - 22 books
# 360. Roy, Lillian Elizabeth, 1868-1932 - 22 books
# 361. Sheckley, Robert, 1928-2005 - 22 books
# 362. Sinclair, May, 1863-1946 - 22 books
# 363. Swift, Jonathan, 1667-1745 - 22 books
# 364. Ainsworth, William Harrison, 1805-1882 - 21 books
# 365. Bellamy, Edward, 1850-1898 - 21 books
# 366. Brackett, Leigh, 1915-1978 - 21 books
# 367. Catherwood, Mary Hartwell, 1847-1902 - 21 books
# 368. Cawein, Madison Julius, 1865-1914 - 21 books
# 369. Cullum, Ridgwell, 1867-1943 - 21 books
# 370. Del Pulgar, Fernando - 21 books
# 371. Del Rey, Lester, 1915-1993 - 21 books
# 372. Dewey, John, 1859-1952 - 21 books
# 373. Douglas, Amanda M., 1831-1916 - 21 books
# 374. Duchess, 1855?-1897 - 21 books
# 375. Ewing, Juliana Horatia, 1841-1885 - 21 books
# 376. Griffiths, Arthur, 1838-1908 - 21 books
# 377. Hill, Grace Livingston, 1865-1947 - 21 books
# 378. Home, Gordon, 1878-1969 - 21 books
# 379. Hudson, W. H. (William Henry), 1841-1922 - 21 books
# 380. Hugo, Victor, 1802-1885 - 21 books
# 381. Leblanc, Maurice, 1864-1941 - 21 books
# 382. Lovecraft, H. P. (Howard Phillips), 1890-1937 - 21 books
# 383. Montgomery, Jemima, Baroness Tautphoeus - 21 books
# 384. Montgomery, L. M. (Lucy Maud), 1874-1942 - 21 books
# 385. Phillpotts, Eden, 1862-1960 - 21 books
# 386. Roberts, B. H. (Brigham Henry), 1857-1933 - 21 books
# 387. Sabatini, Rafael, 1875-1950 - 21 books
# 388. Smith, E. E. (Edward Elmer), 1890-1965 - 21 books
# 389. United States. Central Intelligence Agency - 21 books
# 390. Wade, Mary Hazelton Blanchard, 1860-1936 - 21 books
# 391. Wallace, Alfred Russel, 1823-1913 - 21 books
# 392. Ashton, John, 1834-1911 - 20 books
# 393. Baker, George M. (George Melville), 1832-1890 - 20 books
# 394. Ballou, Maturin M. (Maturin Murray), 1820-1895 - 20 books
# 395. Bedford, Jessie - 20 books
# 396. Bedford-Jones, H. (Henry), 1887-1949 - 20 books
# 397. Brereton, F. S. (Frederick Sadleir), 1872-1957 - 20 books
# 398. Carleton, William, 1794-1869 - 20 books
# 399. Eggleston, George Cary, 1839-1911 - 20 books
# 400. Field, Eugene, 1850-1895 - 20 books
# 401. Fletcher, J. S. (Joseph Smith), 1863-1935 - 20 books
# 402. Frazer, James George, 1854-1941 - 20 books
# 403. Grote, George, 1794-1871 - 20 books
# 404. Harris, Joel Chandler, 1848-1908 - 20 books
# 405. Hazlitt, William, 1778-1830 - 20 books
# 406. Holt, Emily Sarah, 1836-1893 - 20 books
# 407. Honig, Winfried - 20 books
# 408. Jefferies, Richard, 1848-1887 - 20 books
# 409. Knox, Thomas Wallace, 1835-1896 - 20 books
# 410. Lincoln, Joseph Crosby, 1870-1944 - 20 books
# 411. Longeville, Jean - 20 books
# 412. Longfellow, Henry Wadsworth, 1807-1882 - 20 books
# 413. Luther, Martin, 1483-1546 - 20 books
# 414. Maclaren, Alexander, 1826-1910 - 20 books
# 415. Masclary, Bernard, comtesse de - 20 books
# 416. Masefield, John, 1878-1967 - 20 books
# 417. Melville, Herman, 1819-1891 - 20 books
# 418. Morris, Charles, 1833-1922 - 20 books
# 419. Mühlbach, L. (Luise), 1814-1873 - 20 books
# 420. Pansy, 1841-1930 - 20 books
# 421. Phillips, David Graham, 1867-1911 - 20 books
# 422. Sabin, Edwin L. (Edwin Legrand), 1870-1952 - 20 books
# 423. Samachson, Joseph, 1906-1980 - 20 books
# 424. Smith, Evelyn E., 1922-2000 - 20 books
# 425. Speight, T. W. (Thomas Wilkinson), 1830-1915 - 20 books
# 426. Steel, Flora Annie Webster, 1847-1929 - 20 books
# 427. Walpole, Horace, 1717-1797 - 20 books
# 428. Walpole, Hugh, 1884-1941 - 20 books
# Author list saved to /home/lou/Downloads/projects/book_authors/book-authorship-classification/data/input_files/english_20books.txt
